# %% [markdown]
# <a href="https://colab.research.google.com/github/jtlai0921/-/blob/master/yolo_display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import sys
FOLDER_PATH = '/content/drive/My Drive/緯育AI瑕疵檢測/Day3/keras-yolo3'
sys.path.append(FOLDER_PATH)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2

# %%
import numpy as np
import keras.backend as K
from keras.layers import Input, Lambda
from train import yolo_body, get_anchors, create_model, get_classes
from yolo import YOLO
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
import os
# Out:
# Using TensorFlow backend.

# %%
classes_path = os.path.join(FOLDER_PATH, 'model_data/aoi_classes.txt')
class_names = get_classes(classes_path)
num_classes = len(class_names)
anchors_path = os.path.join(FOLDER_PATH, 'model_data/yolo_anchors.txt') 
anchors = get_anchors(anchors_path)

yolo = YOLO(model_path=os.path.join(FOLDER_PATH, 'ep084-loss22.021-val_loss21.299.h5'), 
            classes_path=classes_path,
            anchors_path=anchors_path)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /content/drive/My Drive/緯育AI瑕疵檢測/Day3/keras-yolo3/ep084-loss22.021-val_loss21.299.h5 model, anchors, and classes loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
path = np.random.choice(glob(os.path.join(FOLDER_PATH, 'dataset/train_img/*')), 1)[0]
print(path)
image = Image.open(path)
r_image = yolo.detect_image(image)
r_image.show()
plt.imshow(r_image)
# Out:
# /content/drive/My Drive/緯育AI瑕疵檢測/Day3/keras-yolo3/dataset/train_img/pitted_surface_118.jpg
# (200, 200) (416, 416)
# (416, 416, 3)
# Found 1 boxes for img
# pitted_surface 0.69 (4, 3) (195, 197)
# 8.128091362999982

# %%
path = np.random.choice(glob(os.path.join(FOLDER_PATH, 'dataset/train_img/*')), 1)[0]
print(path)
image = Image.open(path)
r_image = yolo.detect_image(image)
r_image.show()
plt.imshow(r_image)
# Out:
# /content/drive/My Drive/緯育AI瑕疵檢測/Day3/keras-yolo3/dataset/train_img/inclusion_57.jpg
# (200, 200) (416, 416)
# (416, 416, 3)
# Found 1 boxes for img
# inclusion 0.72 (145, 102) (171, 181)
# 0.07501068600001304

# %%
path = np.random.choice(glob(os.path.join(FOLDER_PATH, 'dataset/train_img/*')), 1)[0]
print(path)
image = Image.open(path)
r_image = yolo.detect_image(image)
r_image.show()
plt.imshow(r_image)
# Out:
# /content/drive/My Drive/緯育AI瑕疵檢測/Day3/keras-yolo3/dataset/train_img/scratches_33.jpg
# (200, 200) (416, 416)
# (416, 416, 3)
# Found 1 boxes for img
# scratches 0.50 (109, 27) (127, 179)
# 0.07262611699999866

# %% [markdown]
# ## Yolo pretrained COCO

# %%
classes_path = os.path.join(FOLDER_PATH, 'model_data/coco_classes.txt')
class_names = get_classes(classes_path)
num_classes = len(class_names)
anchors_path = os.path.join(FOLDER_PATH, 'model_data/yolo_anchors.txt')
anchors = get_anchors(anchors_path)

yolo = YOLO(model_path= os.path.join(FOLDER_PATH, 'yolo_weights.h5'),
            classes_path=classes_path,
            anchors_path=anchors_path)
# Out:
# /content/drive/My Drive/緯育AI瑕疵檢測/Day3/keras-yolo3/yolo_weights.h5 model, anchors, and classes loaded.

# %%
path = os.path.join(FOLDER_PATH, 'street.jpeg')
print(path)
image = Image.open(path)
r_image = yolo.detect_image(image)
r_image.show()
plt.figure(figsize=(10,10))
plt.imshow(r_image)
# Out:
# /content/drive/My Drive/class/緯育AI瑕疵檢測/Day3/keras-yolo3/street.jpeg
# (273, 185) (416, 416)
# (416, 416, 3)
# Found 11 boxes for img
# car 0.21 (5, 101) (34, 111)
# car 0.40 (75, 98) (88, 105)
# car 0.50 (55, 98) (77, 106)
# person 0.84 (157, 89) (175, 153)
# person 0.95 (92, 124) (100, 152)
# person 0.95 (83, 128) (91, 156)
# person 0.98 (196, 110) (215, 172)
# person 0.98 (174, 100) (201, 174)
# person 0.98 (146, 106) (165, 169)
# person 0.99 (115, 98) (139, 166)
# person 0.99 (218, 112) (239, 171)
# 2.7048983650000196
